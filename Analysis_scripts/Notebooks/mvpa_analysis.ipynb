# %%
# Importing necessary packages
# %pylab inline
import nipype.interfaces.fsl as fsl
import nipype.interfaces.io as nio
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util
from IPython.display import Image
import os
import glob
import warnings
import shutil
import cPickle
import sys
sys.path.append("/home/lukas/Dropbox/ResMas_UvA/Thesis/Git/Analysis_scripts/modules/")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from glm2mvpa import mvpa_mat
test = cPickle.load(open('/media/lukas/Data/Matlab2Python/FirstLevel/mvpa_mats/hww001_zinnen1.cPickle'))

# %%
test.data.shape
# Out:
# (60, 2374)

# %%
import matplotlib.pyplot as plt
test_cor = np.corrcoef(test.data)
plt.imshow(test_cor)

# %%
np.lowe
